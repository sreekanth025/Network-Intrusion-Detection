# %%
import numpy as np
import glob
import matplotlib.pyplot as plt

# %%
metric_files = glob.glob('../script_outputs/**-metrics.npy')

# %%
agents_metrics = []

for file in metric_files:
    print(file)
    m = np.load(file, allow_pickle=True)
    agents_metrics.append(m.item())
# Out:
# ../script_outputs\client-0-metrics.npy
# ../script_outputs\client-1-metrics.npy

# %%
len(agents_metrics)
# Out:
# 2

# %%
for i in range(len(agents_metrics)):
    plt.plot(agents_metrics[i]['accuracy'])
    plt.show()

# %%
for i in range(len(agents_metrics)):
    plt.plot(agents_metrics[i]['loss'])
    plt.show()

# %%
for i in range(len(agents_metrics)):
    plt.plot(agents_metrics[i]['attention_value'])
plt.show()
